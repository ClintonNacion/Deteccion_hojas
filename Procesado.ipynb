# %% [markdown]
# <a href="https://colab.research.google.com/github/ClintonNacion/Deteccion_hojas/blob/main/Procesado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive_mount')
# Out:
# Mounted at /content/drive_mount

# %% [markdown]
# #Imagenes sanas procesadas

# %% [markdown]
# ##Sanas

# %%
import cv2
import os
import shutil
import numpy as np

# Rutas
input_folder = "/content/drive_mount/MyDrive/Capstone/hoja_sana"
output_folder = "/content/drive_mount/MyDrive/Capstone/hoja_sana_procesadas"

# Crear carpeta de salida limpia
if os.path.exists(output_folder):
    shutil.rmtree(output_folder)
os.makedirs(output_folder)

# Parámetros
blur_threshold = 40.0
target_size = (224, 224)

# Función para verificar borrosidad
def is_blurry(image, threshold=blur_threshold):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    lap_var = cv2.Laplacian(gray, cv2.CV_64F).var()
    return lap_var < threshold

# Función para redimensionar con padding (mantiene aspecto)
def resize_with_padding(image, size=(224, 224)):
    h, w = image.shape[:2]
    scale = min(size[0]/h, size[1]/w)
    new_w, new_h = int(w * scale), int(h * scale)
    resized = cv2.resize(image, (new_w, new_h))

    delta_w = size[1] - new_w
    delta_h = size[0] - new_h
    top, bottom = delta_h // 2, delta_h - (delta_h // 2)
    left, right = delta_w // 2, delta_w - (delta_w // 2)

    # Padding con color negro
    color = [0, 0, 0]
    new_image = cv2.copyMakeBorder(resized, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
    return new_image

# Procesamiento
count = 0
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)
    image = cv2.imread(file_path)

    if image is None:
        continue

    if not is_blurry(image):
        padded = resize_with_padding(image, target_size)
        save_path = os.path.join(output_folder, filename)
        cv2.imwrite(save_path, padded)
        count += 1

print(f"✅ Procesamiento completo Hojas Sanas. Imágenes guardadas: {count}")

# %% [markdown]
# ##Roya

# %%
import cv2
import os
import shutil
import numpy as np

# Rutas
input_folder = "/content/drive_mount/MyDrive/Capstone/roya_kaggle"
output_folder = "/content/drive_mount/MyDrive/Capstone/roya_procesadas"

# Crear carpeta de salida limpia
if os.path.exists(output_folder):
    shutil.rmtree(output_folder)
os.makedirs(output_folder)

# Parámetros
blur_threshold = 40.0
target_size = (224, 224)

# Función para verificar borrosidad
def is_blurry(image, threshold=blur_threshold):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    lap_var = cv2.Laplacian(gray, cv2.CV_64F).var()
    return lap_var < threshold

# Función para redimensionar con padding (mantiene aspecto)
def resize_with_padding(image, size=(224, 224)):
    h, w = image.shape[:2]
    scale = min(size[0]/h, size[1]/w)
    new_w, new_h = int(w * scale), int(h * scale)
    resized = cv2.resize(image, (new_w, new_h))

    delta_w = size[1] - new_w
    delta_h = size[0] - new_h
    top, bottom = delta_h // 2, delta_h - (delta_h // 2)
    left, right = delta_w // 2, delta_w - (delta_w // 2)

    # Padding con color negro
    color = [0, 0, 0]
    new_image = cv2.copyMakeBorder(resized, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
    return new_image

# Procesamiento
count = 0
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)
    image = cv2.imread(file_path)

    if image is None:
        continue

    if not is_blurry(image):
        padded = resize_with_padding(image, target_size)
        save_path = os.path.join(output_folder, filename)
        cv2.imwrite(save_path, padded)
        count += 1

print(f"✅ Procesamiento completo para ROYA. Imágenes guardadas: {count}")

# %% [markdown]
# ##Phoma

# %%
import cv2
import os
import shutil
import numpy as np

# Rutas
input_folder = "/content/drive_mount/MyDrive/Capstone/phoma_kaggle"
output_folder = "/content/drive_mount/MyDrive/Capstone/phoma_procesadas"

# Crear carpeta de salida limpia
if os.path.exists(output_folder):
    shutil.rmtree(output_folder)
os.makedirs(output_folder)

# Parámetros
blur_threshold = 40.0
target_size = (224, 224)

# Función para verificar borrosidad
def is_blurry(image, threshold=blur_threshold):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    lap_var = cv2.Laplacian(gray, cv2.CV_64F).var()
    return lap_var < threshold

# Función para redimensionar con padding (mantiene aspecto)
def resize_with_padding(image, size=(224, 224)):
    h, w = image.shape[:2]
    scale = min(size[0]/h, size[1]/w)
    new_w, new_h = int(w * scale), int(h * scale)
    resized = cv2.resize(image, (new_w, new_h))

    delta_w = size[1] - new_w
    delta_h = size[0] - new_h
    top, bottom = delta_h // 2, delta_h - (delta_h // 2)
    left, right = delta_w // 2, delta_w - (delta_w // 2)

    # Padding con color negro
    color = [0, 0, 0]
    new_image = cv2.copyMakeBorder(resized, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
    return new_image

# Procesamiento
count = 0
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)
    image = cv2.imread(file_path)

    if image is None:
        continue

    if not is_blurry(image):
        padded = resize_with_padding(image, target_size)
        save_path = os.path.join(output_folder, filename)
        cv2.imwrite(save_path, padded)
        count += 1

print(f"✅ Procesamiento completo para Phoma. Imágenes guardadas: {count}")

# %% [markdown]
# ##Minador

# %%
import cv2
import os
import shutil
import numpy as np

# Rutas
input_folder = "/content/drive_mount/MyDrive/Capstone/miner_kaggle"
output_folder = "/content/drive_mount/MyDrive/Capstone/miner_procesadas"

# Crear carpeta de salida limpia
if os.path.exists(output_folder):
    shutil.rmtree(output_folder)
os.makedirs(output_folder)

# Parámetros
blur_threshold = 40.0
target_size = (224, 224)

# Función para verificar borrosidad
def is_blurry(image, threshold=blur_threshold):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    lap_var = cv2.Laplacian(gray, cv2.CV_64F).var()
    return lap_var < threshold

# Función para redimensionar con padding (mantiene aspecto)
def resize_with_padding(image, size=(224, 224)):
    h, w = image.shape[:2]
    scale = min(size[0]/h, size[1]/w)
    new_w, new_h = int(w * scale), int(h * scale)
    resized = cv2.resize(image, (new_w, new_h))

    delta_w = size[1] - new_w
    delta_h = size[0] - new_h
    top, bottom = delta_h // 2, delta_h - (delta_h // 2)
    left, right = delta_w // 2, delta_w - (delta_w // 2)

    # Padding con color negro
    color = [0, 0, 0]
    new_image = cv2.copyMakeBorder(resized, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
    return new_image

# Procesamiento
count = 0
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)
    image = cv2.imread(file_path)

    if image is None:
        continue

    if not is_blurry(image):
        padded = resize_with_padding(image, target_size)
        save_path = os.path.join(output_folder, filename)
        cv2.imwrite(save_path, padded)
        count += 1

print(f"✅ Procesamiento completo para MINADOR. Imágenes guardadas: {count}")

# %% [markdown]
# #Entrenamiento

# %% [markdown]
# ##Creacion de carpetas: dataset

# %%
import os

base_path = '/content/drive_mount/MyDrive/Capstone/dataset'
subdirs = [
    'train/sana', 'train/roya', 'train/phoma', 'train/minador',
    'val/sana', 'val/roya', 'val/phoma', 'val/minador'
]

for subdir in subdirs:
    path = os.path.join(base_path, subdir)
    os.makedirs(path, exist_ok=True)
    print(f"📁 Verificada/creada: {path}")
# Out:
# 📁 Verificada/creada: /content/drive_mount/MyDrive/Capstone/dataset/train/sana
# 📁 Verificada/creada: /content/drive_mount/MyDrive/Capstone/dataset/train/roya
# 📁 Verificada/creada: /content/drive_mount/MyDrive/Capstone/dataset/train/phoma
# 📁 Verificada/creada: /content/drive_mount/MyDrive/Capstone/dataset/train/minador
# 📁 Verificada/creada: /content/drive_mount/MyDrive/Capstone/dataset/val/sana
# 📁 Verificada/creada: /content/drive_mount/MyDrive/Capstone/dataset/val/roya
# 📁 Verificada/creada: /content/drive_mount/MyDrive/Capstone/dataset/val/phoma
# 📁 Verificada/creada: /content/drive_mount/MyDrive/Capstone/dataset/val/minador

# %% [markdown]
# ##Repartir data propia y kaggle 80/20

# %%
import os
import shutil
import random

random.seed(42)

# Configuración de rutas
base_propia = "/content/drive_mount/MyDrive/Capstone/dataset_propia"
base_kaggle = "/content/drive_mount/MyDrive/Capstone/dataset_kaggle"
dest_base = "/content/drive_mount/MyDrive/Capstone/dataset"

# Clases y su proporción
clases = ["sana", "minador", "phoma", "roya"]

for clase in clases:
    print(f"\n🔄 Procesando clase: {clase}")

    # Obtener archivos
    propia_imgs = [os.path.join(base_propia, clase, f) for f in os.listdir(os.path.join(base_propia, clase)) if f.endswith('.jpg')]
    kaggle_imgs = [os.path.join(base_kaggle, clase, f) for f in os.listdir(os.path.join(base_kaggle, clase)) if f.endswith('.jpg')]

    total_imgs = propia_imgs + kaggle_imgs
    random.shuffle(total_imgs)

    # Calcular cortes
    total_count = len(total_imgs)
    train_count = int(total_count * 0.8)

    train_imgs = total_imgs[:train_count]
    val_imgs = total_imgs[train_count:]

    # Función para mover
    def mover(imagenes, destino):
        for img in imagenes:
            filename = os.path.basename(img)
            dest_path = os.path.join(dest_base, destino, clase, filename)
            shutil.copy(img, dest_path)

    mover(train_imgs, "train")
    mover(val_imgs, "val")

    print(f"📁 Train: {len(train_imgs)} imágenes")
    print(f"📁 Val: {len(val_imgs)} imágenes")

print("\n✅ División completada con éxito.")
# Out:
# 🔄 Procesando clase: sana
# 📁 Train: 368 imágenes
# 📁 Val: 93 imágenes
#
# 🔄 Procesando clase: minador
# 📁 Train: 37 imágenes
# 📁 Val: 10 imágenes
#
# 🔄 Procesando clase: phoma
# 📁 Train: 65 imágenes
# 📁 Val: 17 imágenes
#
# 🔄 Procesando clase: roya
# 📁 Train: 58 imágenes
# 📁 Val: 15 imágenes
#
# ✅ División completada con éxito.

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image
import random

base_path = '/content/drive_mount/MyDrive/Capstone/dataset'
train_dir = os.path.join(base_path, 'train')

# Obtener clases
classes = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]

num_images_per_class = 1

fig, axs = plt.subplots(1, len(classes), figsize=(len(classes) * 3, 3))

for i, class_name in enumerate(classes):
    class_path = os.path.join(train_dir, class_name)
    images = os.listdir(class_path)
    random.shuffle(images)
    img_name = images[0]
    img_path = os.path.join(class_path, img_name)
    img = Image.open(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')
    axs[i].set_title(class_name, fontsize=12)

plt.tight_layout()
plt.show()

# %%
# !pip install tensorflow

# %% [markdown]
# ##Oversampling y data augmentación

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import numpy as np

base_train = "/content/drive_mount/MyDrive/Capstone/dataset/train"
clases = ["sana", "minador", "phoma", "roya"]

conteo = {
    "sana": 368,
    "minador": 37,
    "phoma": 65,
    "roya": 58
}

max_count = max(conteo.values())

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

for clase in clases:
    if conteo[clase] == max_count:
        continue  # No necesitamos aumentar esta clase

    carpeta = os.path.join(base_train, clase)
    imgs = [f for f in os.listdir(carpeta) if f.endswith('.jpg')]
    n_imgs = len(imgs)
    faltan = max_count - n_imgs
    print(f"\nClase {clase} tiene {n_imgs} imágenes. Generando {faltan} aumentadas...")

    # Cuántas nuevas imágenes generar por cada imagen original
    aug_por_img = faltan // n_imgs
    extra = faltan % n_imgs

    for i, img_file in enumerate(imgs):
        img_path = os.path.join(carpeta, img_file)
        img = load_img(img_path)
        x = img_to_array(img)
        x = x.reshape((1,) + x.shape)

        total_aug = aug_por_img + (1 if i < extra else 0)
        count = 0

        for batch in datagen.flow(
            x,
            batch_size=1,
            save_to_dir=carpeta,
            save_prefix=f"aug_{i}",
            save_format='jpg'
        ):
            count += 1
            if count >= total_aug:
                break

print("\n✅ Aumento de datos balanceado y diverso completado.")
# Out:
# Clase minador tiene 37 imágenes. Generando 331 aumentadas...
#
# Clase phoma tiene 65 imágenes. Generando 303 aumentadas...
#
# Clase roya tiene 58 imágenes. Generando 310 aumentadas...
#
# ✅ Aumento de datos balanceado y diverso completado.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

print("Imports OK")
# Out:
# Imports OK

# %% [markdown]
# ##Entrenamiento de MobileNetV2

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Configuración
train_dir = "/content/drive_mount/MyDrive/Capstone/dataset/train"
val_dir = "/content/drive_mount/MyDrive/Capstone/dataset/val"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 20
FINE_TUNE_EPOCHS = 20
NUM_CLASSES = 4

# ✅ Data augmentation mejorado
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Cargar base MobileNetV2
base_model = MobileNetV2(input_shape=(*IMG_SIZE, 3),
                         include_top=False,
                         weights='imagenet')
base_model.trainable = False  # congelar inicialmente

# Modelo completo
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.6),  # ✅ Dropout aumentado
    layers.Dense(NUM_CLASSES, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
checkpoint_cb = ModelCheckpoint(
    "mejor_modelo_mobilenetv2.h5",
    save_best_only=True,
    monitor="val_accuracy",
    mode="max",
    verbose=1
)
earlystop_cb = EarlyStopping(
    monitor="val_loss",  # ✅ Mejor para evitar overfitting
    patience=6,
    mode="min",
    restore_best_weights=True,
    verbose=1
)
reduce_lr_cb = ReduceLROnPlateau(
    monitor="val_loss",  # ✅ también mejor
    factor=0.5,
    patience=3,
    verbose=1,
    mode="min",
    min_lr=1e-7
)

# Entrenamiento inicial
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)

# Fine-tuning: descongelar más capas
base_model.trainable = True
fine_tune_at = 60  # ✅ menos capas congeladas para más aprendizaje

for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),  # aprendizaje más lento
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

total_epochs = EPOCHS + FINE_TUNE_EPOCHS

history_fine = model.fit(
    train_generator,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1],
    validation_data=val_generator,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)
# Out:
# Found 1472 images belonging to 4 classes.
# Found 135 images belonging to 4 classes.
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.4319 - loss: 1.4127
# Epoch 1: val_accuracy improved from -inf to 0.75556, saving model to mejor_modelo_mobilenetv2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 576ms/step - accuracy: 0.4333 - loss: 1.4079 - val_accuracy: 0.7556 - val_loss: 0.8021 - learning_rate: 0.0010
# Epoch 2/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.6354 - loss: 0.8582
# Epoch 2: val_accuracy did not improve from 0.75556
# ...

# %%
import matplotlib.pyplot as plt

# Combine training histories
acc = history.history['accuracy'] + history_fine.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']
loss = history.history['loss'] + history_fine.history['loss']
val_loss = history.history['val_loss'] + history_fine.history['val_loss']
epochs_range = range(len(acc))

# Accuracy Curve
plt.figure(figsize=(10, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.axvline(x=EPOCHS-1, color='gray', linestyle='--', label='Fine-Tuning Start')
plt.title('Accuracy Curve - MobileNetV2')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig("mobilenetv2_accuracy_curve.png", dpi=300)
plt.show()

# Loss Curve
plt.figure(figsize=(10, 5))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.axvline(x=EPOCHS-1, color='gray', linestyle='--', label='Fine-Tuning Start')
plt.title('Loss Curve - MobileNetV2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.savefig("mobilenetv2_loss_curve.png", dpi=300)
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Obtener nombres de clases
class_names = list(train_generator.class_indices.keys())

# Predecir en datos de validación
val_preds = model.predict(val_generator)
y_pred = np.argmax(val_preds, axis=1)
y_true = val_generator.classes

# Matriz de confusión
cm = confusion_matrix(y_true, y_pred)

# Mostrar matriz de confusión con seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - MobileNetV2")
plt.tight_layout()
plt.savefig("matriz_confusion_mobilenetv2.png", dpi=300)
plt.show()

# Reporte de clasificación (opcional)
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step
#               precision    recall  f1-score   support
#
#      minador       0.78      0.70      0.74        10
#        phoma       0.78      0.41      0.54        17
#         roya       0.33      0.07      0.11        15
#         sana       0.79      0.97      0.87        93
#
#     accuracy                           0.78       135
#    macro avg       0.67      0.54      0.56       135
# weighted avg       0.74      0.78      0.73       135

# %% [markdown]
# ## ResNet50

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input as preprocess_resnet
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Configuración
train_dir = "/content/drive_mount/MyDrive/Capstone/dataset/train"
val_dir = "/content/drive_mount/MyDrive/Capstone/dataset/val"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 20
FINE_TUNE_EPOCHS = 20
NUM_CLASSES = 4

# ✅ Data augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_resnet,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_resnet)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Cargar base ResNet50
base_model = ResNet50(
    input_shape=(*IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False  # congelar inicialmente

# Modelo completo
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.6),  # ✅ Dropout aumentado
    layers.Dense(NUM_CLASSES, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
checkpoint_cb = ModelCheckpoint(
    "mejor_modelo_resnet50.h5",
    save_best_only=True,
    monitor="val_accuracy",
    mode="max",
    verbose=1
)
earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=6,
    mode="min",
    restore_best_weights=True,
    verbose=1
)
reduce_lr_cb = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=3,
    verbose=1,
    mode="min",
    min_lr=1e-7
)

# Entrenamiento inicial
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)

# Fine-tuning: descongelar desde cierta capa
base_model.trainable = True
fine_tune_at = 140  # ✅ menos capas congeladas

for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),  # tasa de aprendizaje menor
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

total_epochs = EPOCHS + FINE_TUNE_EPOCHS

# Entrenamiento fino
history_fine = model.fit(
    train_generator,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1],
    validation_data=val_generator,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)
# Out:
# Found 1472 images belonging to 4 classes.
# Found 135 images belonging to 4 classes.
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 15s/step - accuracy: 0.4414 - loss: 1.5025
# Epoch 1: val_accuracy improved from -inf to 0.73333, saving model to mejor_modelo_resnet50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
import matplotlib.pyplot as plt
import pickle

# Cargar historial desde archivo .pkl
with open("/content/history_resnet.pkl", "rb") as f:
    history_resnet = pickle.load(f)

# Extraer datos del historial
acc = history_resnet['accuracy']
val_acc = history_resnet['val_accuracy']
loss = history_resnet['loss']
val_loss = history_resnet['val_loss']
epochs_range = range(len(acc))

# Curva de Precisión
plt.figure(figsize=(10, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Accuracy Curve - ResNet50')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig("resnet50_accuracy_curve.png", dpi=300)
plt.show()

# Curva de Pérdida
plt.figure(figsize=(10, 5))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Loss Curve - ResNet50')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.savefig("resnet50_loss_curve.png", dpi=300)
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Asegúrate de que el val_generator tenga shuffle=False (ya lo hiciste bien)

# Obtener nombres de clases
class_names = list(train_generator.class_indices.keys())

# Predecir en datos de validación
val_preds = model.predict(val_generator, steps=val_generator.samples // val_generator.batch_size + 1)
y_pred = np.argmax(val_preds, axis=1)
y_true = val_generator.classes

# Matriz de confusión
cm = confusion_matrix(y_true, y_pred)

# Mostrar matriz de confusión con seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - ResNet50")
plt.tight_layout()
plt.savefig("matriz_confusion_resnet50.png", dpi=300)
plt.show()

# Reporte de clasificación
reporte = classification_report(y_true, y_pred, target_names=class_names)
print(reporte)

# Guardar reporte en .txt
with open("reporte_clasificacion_resnet50.txt", "w") as f:
    f.write(reporte)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step
#               precision    recall  f1-score   support
#
#      minador       0.88      0.70      0.78        10
#        phoma       0.45      0.29      0.36        17
#         roya       1.00      0.13      0.24        15
#         sana       0.80      0.98      0.88        93
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.53      0.56       135
# weighted avg       0.78      0.78      0.73       135

# %% [markdown]
# ##EfficientNetB0

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input as preprocess_effnet

# Data augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_effnet,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_effnet)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Base EfficientNetB0
base_model = EfficientNetB0(
    input_shape=(*IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False

# Modelo completo
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.6),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks (ya definidos previamente)
# Entrenamiento inicial
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)

# Fine-tuning
base_model.trainable = True
fine_tune_at = 200  # EfficientNetB0 tiene ~237 capas
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

history_fine = model.fit(
    train_generator,
    epochs=EPOCHS + FINE_TUNE_EPOCHS,
    initial_epoch=history.epoch[-1],
    validation_data=val_generator,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)
# Out:
# Found 1472 images belonging to 4 classes.
# Found 135 images belonging to 4 classes.
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.4985 - loss: 1.1847
# Epoch 1: val_accuracy did not improve from 0.79259
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 63s 714ms/step - accuracy: 0.4998 - loss: 1.1813 - val_accuracy: 0.7333 - val_loss: 0.8051 - learning_rate: 0.0010
# Epoch 2/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.6625 - loss: 0.7931
# Epoch 2: val_accuracy did not improve from 0.79259
# ...

# %%
import matplotlib.pyplot as plt
import pickle

# Cargar historial desde archivo .pkl
with open("/content/history_effnet.pkl", "rb") as f:
    history_effnet = pickle.load(f)

# Extraer datos del historial
acc = history_effnet['accuracy']
val_acc = history_effnet['val_accuracy']
loss = history_effnet['loss']
val_loss = history_effnet['val_loss']
epochs_range = range(len(acc))

# Curva de Precisión
plt.figure(figsize=(10, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Accuracy Curve - EfficientNetB0')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig("efficientnetb0_accuracy_curve.png", dpi=300)
plt.show()

# Curva de Pérdida
plt.figure(figsize=(10, 5))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Loss Curve - EfficientNetB0')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.savefig("efficientnetb0_loss_curve.png", dpi=300)
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# ✅ Nombres de clases desde val_generator
class_names = list(val_generator.class_indices.keys())

# ✅ Predicciones
val_preds = model.predict(val_generator, steps=val_generator.samples // val_generator.batch_size + 1)
y_pred = np.argmax(val_preds, axis=1)
y_true = val_generator.classes

# ✅ Matriz de Confusión
cm = confusion_matrix(y_true, y_pred)

# ✅ Visualización
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - EfficientNetB0")
plt.tight_layout()
plt.savefig("matriz_confusion_efficientnetb0.png", dpi=300)
plt.show()

# ✅ Reporte
reporte = classification_report(y_true, y_pred, target_names=class_names)
print(reporte)

# ✅ Guardar el reporte
with open("reporte_clasificacion_efficientnetb0.txt", "w") as f:
    f.write(reporte)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step
#               precision    recall  f1-score   support
#
#      minador       0.88      0.70      0.78        10
#        phoma       0.45      0.29      0.36        17
#         roya       1.00      0.13      0.24        15
#         sana       0.80      0.98      0.88        93
#
#     accuracy                           0.78       135
#    macro avg       0.78      0.53      0.56       135
# weighted avg       0.78      0.78      0.73       135

# %% [markdown]
# ##InceptionV3

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input as preprocess_inception

# Data augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_inception,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_inception)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Base InceptionV3
base_model = InceptionV3(
    input_shape=(*IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False

# Modelo completo
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.6),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks (ya definidos)
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)

# Fine-tuning
base_model.trainable = True
fine_tune_at = 250  # InceptionV3 tiene ~311 capas
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

history_fine = model.fit(
    train_generator,
    epochs=EPOCHS + FINE_TUNE_EPOCHS,
    initial_epoch=history.epoch[-1],
    validation_data=val_generator,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)
# Out:
# Found 1472 images belonging to 4 classes.
# Found 135 images belonging to 4 classes.
# ...
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.3279 - loss: 1.7095
# Epoch 1: val_accuracy did not improve from 0.80000
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 52s 729ms/step - accuracy: 0.3296 - loss: 1.7023 - val_accuracy: 0.6000 - val_loss: 1.0813 - learning_rate: 0.0010
# Epoch 2/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.5193 - loss: 1.0935
# Epoch 2: val_accuracy did not improve from 0.80000
# ...

# %%
import matplotlib.pyplot as plt
import pickle

# Cargar historial desde archivo .pkl
with open("/content/history_inception.pkl", "rb") as f:
    history_inception = pickle.load(f)

# Extraer datos
acc = history_inception['accuracy']
val_acc = history_inception['val_accuracy']
loss = history_inception['loss']
val_loss = history_inception['val_loss']
epochs_range = range(len(acc))

# Curva de Precisión
plt.figure(figsize=(10, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Accuracy Curve - InceptionV3')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig("inceptionv3_accuracy_curve.png", dpi=300)
plt.show()

# Curva de Pérdida
plt.figure(figsize=(10, 5))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Loss Curve - InceptionV3')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.savefig("inceptionv3_loss_curve.png", dpi=300)
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# ✅ Obtener nombres de clases
class_names = list(val_generator.class_indices.keys())

# ✅ Realizar predicciones
val_preds = model.predict(val_generator, steps=val_generator.samples // val_generator.batch_size + 1)
y_pred = np.argmax(val_preds, axis=1)
y_true = val_generator.classes

# ✅ Matriz de confusión
cm = confusion_matrix(y_true, y_pred)

# ✅ Visualización de la matriz
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - InceptionV3")
plt.tight_layout()
plt.savefig("matriz_confusion_inceptionv3.png", dpi=300)
plt.show()

# ✅ Reporte de clasificación
reporte = classification_report(y_true, y_pred, target_names=class_names)
print(reporte)

# ✅ Guardar reporte
with open("reporte_clasificacion_inceptionv3.txt", "w") as f:
    f.write(reporte)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step
#               precision    recall  f1-score   support
#
#      minador       0.70      0.70      0.70        10
#        phoma       0.70      0.41      0.52        17
#         roya       0.67      0.13      0.22        15
#         sana       0.79      0.96      0.87        93
#
#     accuracy                           0.78       135
#    macro avg       0.72      0.55      0.58       135
# weighted avg       0.76      0.78      0.74       135

# %% [markdown]
# ## Curva de aprendizaje de los 4 modelos

# %%
import pickle
import matplotlib.pyplot as plt

# Cargar historiales desde archivos
with open("/content/history_resnet.pkl", "rb") as f:
    history_resnet = pickle.load(f)

with open("/content/history_effnet.pkl", "rb") as f:
    history_effnet = pickle.load(f)

with open("/content/history_inception.pkl", "rb") as f:
    history_inception = pickle.load(f)

# Suponiendo que estas variables ya existen desde entrenamiento de MobileNetV2
full_history_mobilenet = {
    'accuracy': history.history['accuracy'] + history_fine.history['accuracy'],
    'val_accuracy': history.history['val_accuracy'] + history_fine.history['val_accuracy'],
    'loss': history.history['loss'] + history_fine.history['loss'],
    'val_loss': history.history['val_loss'] + history_fine.history['val_loss'],
}

# === Gráfica de Precisión ===
plt.figure(figsize=(10, 6))
plt.plot(full_history_mobilenet['val_accuracy'], label='MobileNetV2')
plt.plot(history_resnet['val_accuracy'], label='ResNet50')
plt.plot(history_effnet['val_accuracy'], label='EfficientNetB0')
plt.plot(history_inception['val_accuracy'], label='InceptionV3')
plt.title('Validation Accuracy Comparison')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("accuracy_comparison.png", dpi=300)
plt.show()

# === Gráfica de Pérdida ===
plt.figure(figsize=(10, 6))
plt.plot(full_history_mobilenet['val_loss'], label='MobileNetV2')
plt.plot(history_resnet['val_loss'], label='ResNet50')
plt.plot(history_effnet['val_loss'], label='EfficientNetB0')
plt.plot(history_inception['val_loss'], label='InceptionV3')
plt.title('Validation Loss Comparison')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("loss_comparison.png", dpi=300)
plt.show()

# === Comparación final (última epoch) ===
print("🔍 Final Validation Accuracy:")
print("MobileNetV2:", round(full_history_mobilenet['val_accuracy'][-1], 4))
print("ResNet50:", round(history_resnet['val_accuracy'][-1], 4))
print("EfficientNetB0:", round(history_effnet['val_accuracy'][-1], 4))
print("InceptionV3:", round(history_inception['val_accuracy'][-1], 4))
# Out:
# 🔍 Final Validation Accuracy:
# MobileNetV2: 0.7852
# ResNet50: 0.8148
# EfficientNetB0: 0.7852
# InceptionV3: 0.6667

# %% [markdown]
# ## Entrenamiento de Inception, etc

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50, EfficientNetB0, InceptionV3
from tensorflow.keras.applications.resnet50 import preprocess_input as preprocess_resnet
from tensorflow.keras.applications.efficientnet import preprocess_input as preprocess_effnet
from tensorflow.keras.applications.inception_v3 import preprocess_input as preprocess_inception
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Rutas a tus carpetas de datos
train_dir = '/content/drive/MyDrive/Capstone/dataset/train'
val_dir = '/content/drive/MyDrive/Capstone/dataset/val'

batch_size = 32
num_classes = 4

# Generadores para ResNet50 y EfficientNet-B0 (224x224)
train_gen_224 = ImageDataGenerator(preprocessing_function=None)
val_gen_224 = ImageDataGenerator(preprocessing_function=None)

train_generator_224_resnet = train_gen_224.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator_224_resnet = val_gen_224.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # IMPORTANTE para matriz de confusión
)

# Generadores para InceptionV3 (299x299)
train_gen_299 = ImageDataGenerator(preprocessing_function=None)
val_gen_299 = ImageDataGenerator(preprocessing_function=None)

train_generator_299_inception = train_gen_299.flow_from_directory(
    train_dir,
    target_size=(299, 299),
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator_299_inception = val_gen_299.flow_from_directory(
    val_dir,
    target_size=(299, 299),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # IMPORTANTE para matriz de confusión
)

def create_model(base_model_class, input_shape, preprocess_func):
    base_model = base_model_class(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = False

    inputs = layers.Input(shape=input_shape)
    x = preprocess_func(inputs) if preprocess_func else inputs
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    return model

def plot_confusion_matrix(model, val_generator, class_names, title):
    y_pred_prob = model.predict(val_generator)
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_true = val_generator.classes
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(title)
    plt.show()

model_resnet = create_model(ResNet50, (224, 224, 3), preprocess_resnet)
model_effnet = create_model(EfficientNetB0, (224, 224, 3), preprocess_effnet)
model_inception = create_model(InceptionV3, (299, 299, 3), preprocess_inception)

for model in [model_resnet, model_effnet, model_inception]:
    model.compile(
        optimizer=optimizers.Adam(),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ReduceLROnPlateau(patience=3)
]

# Entrenar ResNet50 y mostrar matriz de confusión
print("Entrenando ResNet50...")
history_resnet = model_resnet.fit(
    train_generator_224_resnet,
    validation_data=val_generator_224_resnet,
    epochs=20,
    callbacks=callbacks
)
class_names_224 = list(val_generator_224_resnet.class_indices.keys())
plot_confusion_matrix(model_resnet, val_generator_224_resnet, class_names_224, "Matriz de Confusión ResNet50")

# Entrenar EfficientNet-B0 y mostrar matriz de confusión
print("Entrenando EfficientNet-B0...")
history_effnet = model_effnet.fit(
    train_generator_224_resnet,
    validation_data=val_generator_224_resnet,
    epochs=20,
    callbacks=callbacks
)
plot_confusion_matrix(model_effnet, val_generator_224_resnet, class_names_224, "Matriz de Confusión EfficientNet-B0")

# Entrenar InceptionV3 y mostrar matriz de confusión
print("Entrenando InceptionV3...")
history_inception = model_inception.fit(
    train_generator_299_inception,
    validation_data=val_generator_299_inception,
    epochs=20,
    callbacks=callbacks
)
class_names_299 = list(val_generator_299_inception.class_indices.keys())
plot_confusion_matrix(model_inception, val_generator_299_inception, class_names_299, "Matriz de Confusión InceptionV3")
# Out:
# Found 1450 images belonging to 4 classes.
# Found 133 images belonging to 4 classes.
# Found 1450 images belonging to 4 classes.
# Found 133 images belonging to 4 classes.
# Entrenando ResNet50...
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 27s 363ms/step - accuracy: 0.6216 - loss: 0.9241 - val_accuracy: 0.6992 - val_loss: 0.8540 - learning_rate: 0.0010
# Epoch 2/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - accuracy: 0.9072 - loss: 0.3104 - val_accuracy: 0.7444 - val_loss: 0.7299 - learning_rate: 0.0010
# Epoch 3/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.9023 - loss: 0.2596 - val_accuracy: 0.7594 - val_loss: 0.7377 - learning_rate: 0.0010
# Epoch 4/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.9137 - loss: 0.2282 - val_accuracy: 0.7744 - val_loss: 0.6977 - learning_rate: 0.0010
# Epoch 5/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9402 - loss: 0.1821 - val_accuracy: 0.7895 - val_loss: 0.7572 - learning_rate: 0.0010
# Epoch 6/20
# ...
